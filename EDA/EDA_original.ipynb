# %%
from sklearn.impute import KNNImputer
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import missingno as msno

file_path = "D:\Jupyter_Project\ML_Team\Data\2year.csv"
df = pd.read_csv(r"D:\Jupyter_Project\ML_Team\Data\2year.csv")
df.head()
# Out:
#    id     attr1    attr2     attr3   attr4   attr5     attr6    attr7  \
# 0   1  0.202350  0.46500  0.240380  1.5171 -14.547  0.510690  0.25366
# 1   2  0.030073  0.59563  0.186680  1.3382 -37.859 -0.000319  0.04167
# 2   3  0.257860  0.29949  0.665190  3.2211  71.799  0.000000  0.31877
# 3   4  0.227160  0.67850  0.042784  1.0828 -88.212  0.000000  0.28505
# 4   5  0.085443  0.38039  0.359230  1.9444  21.731  0.187900  0.10823
#
#      attr8    attr9  ...   attr56    attr57   attr58   attr59  attr60  \
# 0  0.91816  1.15190  ...  0.13184  0.473950  0.86816  0.00024  8.5487
# 1  0.67890  0.32356  ...  0.12146  0.074369  0.87235  0.00000  1.5264
# 2  2.33200  1.67620  ...  0.16499  0.369210  0.81614  0.00000  4.3325
# 3  0.47384  1.32410  ...  0.29358  0.706570  0.78617  0.48456  5.2309
# 4  1.37140  1.11260  ...  0.10124  0.163790  0.89876  0.00000  5.7035
#
#     attr61   attr62   attr63   attr64  bankruptcy
# 0  5.16550  107.740  3.38790   5.3440           0
# 1  0.63305  622.660  0.58619   1.2381           0
# 2  3.19850   65.215  5.59690  47.4660           0
# 3  5.06750  142.460  2.56210   3.0066           0
# 4  4.00200   89.058  4.09840   5.9874           0
#
# [5 rows x 66 columns]

# %% [markdown]
# # ID 제거

# %%
df = df.drop(["id"],axis=1)

# %% [markdown]
# # 중복 데이터 확인

# %%
if df.duplicated().sum()>0:
    # 중복제거
    print("중복 데이터 Check!")
    print("중복된 데이터 수 : ",df.duplicated().sum())
    df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=True)
    print("제거 후 :" ,df.duplicated().sum())
# Out:
# 중복 데이터 Check!
# 중복된 데이터 수 :  90
# 제거 후 : 0

# %% [markdown]
# # 결측치 확인

# %%
msno.bar(df=df.iloc[:, :], color=(0.1, 0.6, 0.8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # KNN 결측치 대체 방법

# %%
df_columns = df.columns
imputer=KNNImputer(n_neighbors=5)
df = imputer.fit_transform(df)
df = pd.DataFrame(df, columns = df_columns)
df
# Out:
#           attr1    attr2     attr3    attr4      attr5     attr6     attr7  \
# 0      0.202350  0.46500  0.240380  1.51710  -14.54700  0.510690  0.253660
# 1      0.030073  0.59563  0.186680  1.33820  -37.85900 -0.000319  0.041670
# 2      0.257860  0.29949  0.665190  3.22110   71.79900  0.000000  0.318770
# 3      0.227160  0.67850  0.042784  1.08280  -88.21200  0.000000  0.285050
# 4      0.085443  0.38039  0.359230  1.94440   21.73100  0.187900  0.108230
# ...         ...      ...       ...      ...        ...       ...       ...
# 10078  0.029970  0.66806  0.066243  1.11030 -105.55000  0.029970  0.038888
# 10079  0.012843  0.49306 -0.160620  0.61898  -24.80100  0.012843  0.012843
# 10080  0.015092  0.55759 -0.284600  0.48599  -85.57100  0.015092  0.009826
# 10081 -0.002554  0.47076  0.424010  1.90070    0.95483 -0.002554  0.001785
# 10082  0.002072  0.94315 -0.134740  0.85607 -119.92000  0.015226  0.002072
#
#           attr8    attr9    attr10  ...    attr56    attr57   attr58  \
# 0      0.918160  1.15190  0.426950  ...  0.131840  0.473950  0.86816
# 1      0.678900  0.32356  0.404370  ...  0.121460  0.074369  0.87235
# 2      2.332000  1.67620  0.698410  ...  0.164990  0.369210  0.81614
# 3      0.473840  1.32410  0.321500  ...  0.293580  0.706570  0.78617
# 4      1.371400  1.11260  0.521670  ...  0.101240  0.163790  0.89876
# ...         ...      ...       ...  ...       ...       ...      ...
# 10078  0.482740  1.02920  0.322500  ...  0.028377  0.092931  0.97162
# 10079  0.905900  1.01450  0.446660  ...  0.014247  0.028752  0.98575
# 10080  0.694880  1.00600  0.387460  ...  0.005971  0.038950  0.99403
# 10081  1.114400  0.99293  0.524640  ... -0.007122 -0.004869  1.00710
# 10082  0.059818  1.77490  0.056417  ...  0.031154  0.036720  0.96220
#
#          attr59   attr60    attr61   attr62   attr63   attr64  bankruptcy
# 0      0.000240   8.5487   5.16550  107.740  3.38790   5.3440         0.0
# 1      0.000000   1.5264   0.63305  622.660  0.58619   1.2381         0.0
# 2      0.000000   4.3325   3.19850   65.215  5.59690  47.4660         0.0
# 3      0.484560   5.2309   5.06750  142.460  2.56210   3.0066         0.0
# 4      0.000000   5.7035   4.00200   89.058  4.09840   5.9874         0.0
# ...         ...      ...       ...      ...      ...      ...         ...
# 10078  0.209820   3.0914   3.94560  192.220  1.89880   3.4199         1.0
# 10079  0.160090  48.6660  63.75200   40.071  9.10870   5.1956         1.0
# 10080  0.010091  15.0530  11.96400  114.250  3.19480   2.4201         1.0
# 10081  0.000000   6.4289   5.70250   64.291  5.67730  25.3990         1.0
# 10082  0.132800   4.1618   4.97340  192.510  1.89600   8.9562         1.0
#
# [10083 rows x 65 columns]

# %%
msno.bar(df=df.iloc[:, :], color=(0.1, 0.6, 0.8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## X, Y , column Name 추출

# %%
X = df.drop(labels=['bankruptcy'], axis=1)
y = df['bankruptcy']
col_names = X.columns

# %% [markdown]
# # Histogram

# %%
df.drop(labels=["bankruptcy"],axis=1).hist(bins = 50, figsize = (35,20))
plt.show()

# %% [markdown]
# # 이상치 확인

# %%
# create a 3x3 grid of subplots
f,a = plt.subplots(10,3, figsize=(15, 35))
a = a.ravel()
k=0
for idx,ax in enumerate(a):
    sns.boxplot(data=df[col_names[k]],color="red",ax=ax)
    ax.set_title(col_names[k])
    #ax.legend()
    k+=1
plt.tight_layout()

# %%
# create a 3x3 grid of subplots
f,a = plt.subplots(10,3, figsize=(15, 35))
a = a.ravel()
for idx,ax in enumerate(a):
    if k >= len(col_names):
        break
    sns.boxplot(data=df[col_names[k]],color="red",ax=ax)
    ax.set_title(col_names[k])
    #ax.legend()
    k+=1
plt.tight_layout()

# %%
# create a 3x3 grid of subplots
f,a = plt.subplots(10,3, figsize=(15, 35))
a = a.ravel()
for idx,ax in enumerate(a):
    if k >= len(col_names):
        break
    sns.boxplot(data=df[col_names[k]],color="red",ax=ax)
    ax.set_title(col_names[k])
    #ax.legend()
    k+=1
plt.tight_layout()

# %% [markdown]
# ## 클래스 별(Bankruptcy, Non-Bankruptcy) 이상치 확인

# %%
import math

# %%
def plot_boxplots(df):
    n=len(df.columns)
    plt.subplots(math.ceil(n/4),4,figsize=(20,8*math.ceil(n/5)))
    plt.grid('off')
    
    for i,col in enumerate(df.drop('bankruptcy',axis=1).columns):
        plt.subplot(math.ceil(n/4),4,i+1)
        
        sns.boxplot(x='bankruptcy',y=col,data=df)
        plt.title(f'{col}')
        
    plt.tight_layout()
    plt.show()
plot_boxplots(df)

# %% [markdown]
# # 산점도 확인

# %%
# scatter plot
# create a 3x3 grid of subplots
f,a = plt.subplots(10,3, figsize=(15, 35))
Y = df.bankruptcy.values
a = a.ravel()
k=0
for idx,ax in enumerate(a):
    X= df[col_names[k]].values
    ax.scatter(X,Y)
    ax.set_title(col_names[k]+"~bankruptcy")
    k+=1
plt.tight_layout()

# %%
# scatter plot
# create a 3x3 grid of subplots
f,a = plt.subplots(10,3, figsize=(15, 35))
Y = df.bankruptcy.values
a = a.ravel()
for idx,ax in enumerate(a):
    X= df[col_names[k]].values
    ax.scatter(X,Y)
    ax.set_title(col_names[k]+"~bankruptcy")
    k+=1
plt.tight_layout()

# %%
# scatter plot
# create a 3x3 grid of subplots
f,a = plt.subplots(10,3, figsize=(15, 35))
Y = df.bankruptcy.values
a = a.ravel()
for idx,ax in enumerate(a):
    if k >= len(col_names):
        break
    X= df[col_names[k]].values
    ax.scatter(X,Y)
    ax.set_title(col_names[k]+"~bankruptcy")
    k+=1
plt.tight_layout()

# %% [markdown]
# # Scaling

# %%
def index_reset(data):
    Y = df['bankruptcy']
    data=data.reset_index()
    data=data.drop(labels=['index'], axis=1)
    Y= Y.reset_index()
    Y= Y.drop(labels=['index'], axis=1)
    data['bankruptcy']=Y
    return data

# %% [markdown]
# ## 표준화만 하기!

# %%
#스케일링 전처리 , feature 값과 Y값 분리 
X = df.drop(labels=['bankruptcy'], axis=1)
col_names = X.columns

from sklearn.preprocessing import StandardScaler
scaler_std = StandardScaler()
scaled_standard = scaler_std.fit_transform(X)
standard_df = pd.DataFrame(scaled_standard, columns=col_names)

standard_df = index_reset(standard_df)
standard_df.head()

# %% [markdown]
# ## 정규화만 하기!

# %%
#스케일링 전처리 , feature 값과 Y값 분리 
X = df.drop(labels=['bankruptcy'], axis=1)
col_names = X.columns

from sklearn.preprocessing import MinMaxScaler

scaler_nor = MinMaxScaler()
norm_array = scaler_nor.fit_transform(X)
normal_df = pd.DataFrame(norm_array, columns=col_names)

normal_df = index_reset(normal_df)
normal_df.head()

# %% [markdown]
# ## 표준화, 정규화 둘 다 하기!

# %%
#스케일링 전처리 , feature 값과 Y값 분리 
X = df.drop(labels=['bankruptcy'], axis=1)
col_names = X.columns

from sklearn.preprocessing import StandardScaler
scaler_std = StandardScaler()
df_standard = scaler_std.fit_transform(X)

# 정규화
from sklearn.preprocessing import MinMaxScaler
scaler_nor = MinMaxScaler()
norm_array = scaler_nor.fit_transform(df_standard)
SN_df = pd.DataFrame(norm_array, columns=col_names)

SN_df = index_reset(SN_df)
SN_df.head()

# %%
df= SN_df

# %% [markdown]
# # Correlation Matrix

# %% [markdown]
# ## heat map

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize = (15,15))
sns.heatmap(corr, ax = ax, cmap = 'viridis', linewidth = 0.1)

# %% [markdown]
# ## 상관계수가 0.4 이상이면 상관성이 높다고 판단합니다.

# %%
mask=np.zeros_like(df.corr(),dtype=np.bool)
mask[np.triu_indices_from(mask)]=True
corr = df.corr()
kot = corr[corr>=.4]
plt.figure(figsize=(15,7))
sns.heatmap(kot, cmap="Greens",annot=True, annot_kws={"size": 3},mask=mask)

# %% [markdown]
# ## 상관 계수를 순서대로 정렬합니다.

# %%
pip install plotly

# %%
# Data
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

#warning
import warnings
warnings.filterwarnings('ignore')

# %%
corr_df = df.corr()
corr_df = corr_df.apply(lambda x: round(x ,2))
corr_df

# %%
s = corr_df.unstack()
s
# Out:
# attr1       attr1         1.00
#             attr2         0.27
#             attr3        -0.27
#             attr4         0.00
#             attr5        -0.00
#                           ...
# bankruptcy  attr61       -0.01
#             attr62        0.01
#             attr63       -0.00
#             attr64       -0.00
#             bankruptcy    1.00
# Length: 4225, dtype: float64

# %%
# Series이므로 DataFrame으로 변경한다. 
df_corr = pd.DataFrame(s[s < 1].sort_values(ascending=False), columns=['corr'])
df_corr.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_08bef_row0_col0, #T_08bef_row1_col0, #T_08bef_row2_col0, #T_08bef_row3_col0, #T_08bef_row4_col0, #T_08bef_row5_col0, #T_08bef_row6_col0, #T_08bef_row7_col0, #T_08bef_row8_col0, #T_08bef_row9_col0, #T_08bef_row10_col0, #T_08bef_row11_col0, #T_08bef_row12_col0, #T_08bef_row13_col0, #T_08bef_row14_col0, #T_08bef_row15_col0, #T_08bef_row16_col0, #T_08bef_row17_col0, #T_08bef_row18_col0, #T_08bef_row19_col0, #T_08bef_row20_col0, #T_08bef_row21_col0, #T_08bef_row22_col0, #T_08bef_row23_col0, #T_08bef_row24_col0, #T_08bef_row25_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_08bef_row26_col0, #T_08bef_row27_col0, #T_08bef_row28_col0, #T_08bef_row29_col0, #T_08bef_row30_col0, #T_08bef_row31_col0 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_08bef_row32_col0, #T_08bef_row33_col0, #T_08bef_row34_col0, #T_08bef_row35_col0, #T_08bef_row36_col0, #T_08bef_row37_col0 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_08bef_row38_col0, #T_08bef_row39_col0, #T_08bef_row40_col0, #T_08bef_row41_col0, #T_08bef_row42_col0, #T_08bef_row43_col0, #T_08bef_row44_col0, #T_08bef_row45_col0 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_08bef_row46_col0, #T_08bef_row47_col0, #T_08bef_row48_col0, #T_08bef_row49_col0, #T_08bef_row50_col0, #T_08bef_row51_col0, #T_08bef_row52_col0, #T_08bef_row53_col0, #T_08bef_row54_col0, #T_08bef_row55_col0 {
#   background-color: #efe51c;
#   color: #000000;
# }
# #T_08bef_row56_col0, #T_08bef_row57_col0 {
#   background-color: #ece51b;
#   color: #000000;
# }
# #T_08bef_row58_col0, #T_08bef_row59_col0 {
#   background-color: #e5e419;
#   color: #000000;
# }
# #T_08bef_row60_col0, #T_08bef_row61_col0 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_08bef_row62_col0, #T_08bef_row63_col0, #T_08bef_row64_col0, #T_08bef_row65_col0, #T_08bef_row66_col0, #T_08bef_row67_col0, #T_08bef_row68_col0, #T_08bef_row69_col0 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_08bef_row70_col0, #T_08bef_row71_col0, #T_08bef_row72_col0, #T_08bef_row73_col0, #T_08bef_row74_col0, #T_08bef_row75_col0, #T_08bef_row76_col0, #T_08bef_row77_col0 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_08bef_row78_col0, #T_08bef_row79_col0, #T_08bef_row80_col0, #T_08bef_row81_col0, #T_08bef_row82_col0, #T_08bef_row83_col0, #T_08bef_row84_col0, #T_08bef_row85_col0, #T_08bef_row86_col0, #T_08bef_row87_col0, #T_08bef_row88_col0, #T_08bef_row89_col0, #T_08bef_row90_col0, #T_08bef_row91_col0, #T_08bef_row92_col0, #T_08bef_row93_col0 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_08bef_row94_col0, #T_08bef_row95_col0, #T_08bef_row96_col0, #T_08bef_row97_col0, #T_08bef_row98_col0, #T_08bef_row99_col0, #T_08bef_row100_col0, #T_08bef_row101_col0 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_08bef_row102_col0, #T_08bef_row103_col0 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_08bef_row104_col0, #T_08bef_row105_col0 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_08bef_row106_col0, #T_08bef_row107_col0, #T_08bef_row108_col0, #T_08bef_row109_col0 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_08bef_row110_col0, #T_08bef_row111_col0, #T_08bef_row112_col0, #T_08bef_row113_col0, #T_08bef_row114_col0, #T_08bef_row115_col0, #T_08bef_row116_col0, #T_08bef_row117_col0 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_08bef_row118_col0, #T_08bef_row119_col0, #T_08bef_row120_col0, #T_08bef_row121_col0, #T_08bef_row122_col0, #T_08bef_row123_col0, #T_08bef_row124_col0, #T_08bef_row125_col0, #T_08bef_row126_col0, #T_08bef_row127_col0, #T_08bef_row128_col0, #T_08bef_row129_col0 {
#   background-color: #9dd93b;
#   color: #000000;
# }
# #T_08bef_row130_col0, #T_08bef_row131_col0 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_08bef_row132_col0, #T_08bef_row133_col0 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_08bef_row134_col0, #T_08bef_row135_col0, #T_08bef_row136_col0, #T_08bef_row137_col0 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_08bef_row138_col0, #T_08bef_row139_col0, #T_08bef_row140_col0, #T_08bef_row141_col0, #T_08bef_row142_col0, #T_08bef_row143_col0 {
#   background-color: #8ed645;
#   color: #000000;
# }
# #T_08bef_row144_col0, #T_08bef_row145_col0 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_08bef_row146_col0, #T_08bef_row147_col0 {
#   background-color: #86d549;
#   color: #000000;
# }
# #T_08bef_row148_col0, #T_08bef_row149_col0, #T_08bef_row150_col0, #T_08bef_row151_col0, #T_08bef_row152_col0, #T_08bef_row153_col0 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_08bef_row154_col0, #T_08bef_row155_col0, #T_08bef_row156_col0, #T_08bef_row157_col0, #T_08bef_row158_col0, #T_08bef_row159_col0 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_08bef_row160_col0, #T_08bef_row161_col0 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_08bef_row162_col0, #T_08bef_row163_col0, #T_08bef_row164_col0, #T_08bef_row165_col0 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_08bef_row166_col0, #T_08bef_row167_col0 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_08bef_row168_col0, #T_08bef_row169_col0, #T_08bef_row170_col0, #T_08bef_row171_col0, #T_08bef_row172_col0, #T_08bef_row173_col0, #T_08bef_row174_col0, #T_08bef_row175_col0, #T_08bef_row176_col0, #T_08bef_row177_col0, #T_08bef_row178_col0, #T_08bef_row179_col0, #T_08bef_row180_col0, #T_08bef_row181_col0, #T_08bef_row182_col0, #T_08bef_row183_col0, #T_08bef_row184_col0, #T_08bef_row185_col0, #T_08bef_row186_col0, #T_08bef_row187_col0, #T_08bef_row188_col0, #T_08bef_row189_col0, #T_08bef_row190_col0, #T_08bef_row191_col0 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_08bef_row192_col0, #T_08bef_row193_col0, #T_08bef_row194_col0, #T_08bef_row195_col0, #T_08bef_row196_col0, #T_08bef_row197_col0, #T_08bef_row198_col0, #T_08bef_row199_col0, #T_08bef_row200_col0, #T_08bef_row201_col0 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_08bef_row202_col0, #T_08bef_row203_col0, #T_08bef_row204_col0, #T_08bef_row205_col0, #T_08bef_row206_col0, #T_08bef_row207_col0, #T_08bef_row208_col0, #T_08bef_row209_col0, #T_08bef_row210_col0, #T_08bef_row211_col0 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_08bef_row212_col0, #T_08bef_row213_col0, #T_08bef_row214_col0, #T_08bef_row215_col0 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_08bef_row216_col0, #T_08bef_row217_col0, #T_08bef_row218_col0, #T_08bef_row219_col0, #T_08bef_row220_col0, #T_08bef_row221_col0 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_08bef_row222_col0, #T_08bef_row223_col0 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_08bef_row224_col0, #T_08bef_row225_col0 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_08bef_row226_col0, #T_08bef_row227_col0 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_08bef_row228_col0, #T_08bef_row229_col0, #T_08bef_row230_col0, #T_08bef_row231_col0, #T_08bef_row232_col0, #T_08bef_row233_col0, #T_08bef_row234_col0, #T_08bef_row235_col0, #T_08bef_row236_col0, #T_08bef_row237_col0, #T_08bef_row238_col0, #T_08bef_row239_col0 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_08bef_row240_col0, #T_08bef_row241_col0 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_08bef_row242_col0, #T_08bef_row243_col0, #T_08bef_row244_col0, #T_08bef_row245_col0 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_08bef_row246_col0, #T_08bef_row247_col0, #T_08bef_row248_col0, #T_08bef_row249_col0 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# #T_08bef_row250_col0, #T_08bef_row251_col0 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_08bef_row252_col0, #T_08bef_row253_col0, #T_08bef_row254_col0, #T_08bef_row255_col0, #T_08bef_row256_col0, #T_08bef_row257_col0 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_08bef_row258_col0, #T_08bef_row259_col0 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_08bef_row260_col0, #T_08bef_row261_col0 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_08bef_row262_col0, #T_08bef_row263_col0, #T_08bef_row264_col0, #T_08bef_row265_col0, #T_08bef_row266_col0, #T_08bef_row

# %% [markdown]
# ## 상관계수가 잘 보이는 Matrix

# %%
corr=df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_681be_row0_col0, #T_681be_row0_col6, #T_681be_row0_col13, #T_681be_row1_col1, #T_681be_row1_col50, #T_681be_row2_col2, #T_681be_row2_col9, #T_681be_row2_col24, #T_681be_row2_col37, #T_681be_row3_col3, #T_681be_row3_col45, #T_681be_row3_col49, #T_681be_row4_col4, #T_681be_row5_col5, #T_681be_row6_col0, #T_681be_row6_col6, #T_681be_row6_col13, #T_681be_row7_col7, #T_681be_row7_col16, #T_681be_row8_col8, #T_681be_row9_col2, #T_681be_row9_col9, #T_681be_row9_col24, #T_681be_row9_col37, #T_681be_row10_col10, #T_681be_row11_col11, #T_681be_row12_col12, #T_681be_row13_col0, #T_681
col13 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_681be_row0_col4, #T_681be_row0_col20, #T_681be_row0_col36, #T_681be_row1_col11, #T_681be_row1_col20, #T_681be_row1_col26, #T_681be_row2_col20, #T_681be_row2_col36, #T_681be_row2_col64, #T_681be_row3_col20, #T_681be_row4_col20, #T_681be_row5_col20, #T_681be_row5_col36, #T_681be_row5_col64, #T_681be_row6_col4, #T_681be_row6_col20, #T_681be_row6_col36, #T_681be_row7_col20, #T_681be_row8_col4, #T_681be_row8_col20, #T_681be_row8_col47, #T_681be_row9_col20, #T_681be_row9_col36, #T_681be_row9_col64, #T_681be_row10_col4, #T_681be_row10_col20, #T_681be_row10_col36, #T_681be_row11_col20, #T_681be_row12_col4, #T_681be_row12_col20, #T_681be_row13_col4, #T_681be_row13_col20, #T_681be_row13_col36, #T_681be_row14_col4, #T_681be_row14_col20, #T_681be_row15_col20, #T_681be_row16_col20, #T_681be_row17_col4, #T_681be_row17_col20, #T_681be_row17_col36, #T_681be_row18_col4, #T_681be_row18_col15, #T_681be_row18_col20, #T_681be_row18_col25, #T_681be_row19_col4, #T_681be_row20_col4, #T_681be_row21_col20, #T_681be_row22_col4, #T_681be_row22_col15, #T_681be_row22_col20, #T_681be_row22_col25, #T_681be_row23_col20, #T_681be_row23_col36, #T_681be_row23_col64, #T_681be_row24_col0, #T_681be_row24_col6, #T_681be_row24_col10, #T_681be_row24_col13, #T_681be_row24_col17, #T_681be_row24_col20, #T_681be_row24_col36, #T_681be_row25_col20, #T_681be_row26_col20, #T_681be_row27_col20, #T_681be_row28_col4, #T_681be_row28_col40, #T_681be_row30_col4, #T_681be_row30_col15, #T_681be_row30_col20, #T_681be_row30

# %% [markdown]
# # 정규분포(확률 밀도 함수) 확인

# %%
from scipy.stats import norm

# %%
normal_df = df.loc[df["bankruptcy"]==0,:]
abnormal_df = df.loc[df["bankruptcy"]==1,:]

# %%
# create a 3x3 grid of subplots
f,a = plt.subplots(10,3, figsize=(15, 35))
a = a.ravel()
k=0
for idx,ax in enumerate(a):
    ax.hist(normal_df[col_names[k]], color = 'green', alpha = 0.2, bins = 100, range = [-1, 1], label = '0',density=True )
    ax.hist(abnormal_df[col_names[k]], color = 'red', alpha = 0.2, bins = 100, range = [-1, 1], label = '1',density=True)
    ax.legend()
    ax.set_title(col_names[k])
    k+=1
plt.tight_layout()

# %%
# create a 3x3 grid of subplots
f,a = plt.subplots(10,3, figsize=(15, 35))
a = a.ravel()
for idx,ax in enumerate(a):
    if k >= len(col_names):
        break
    ax.hist(normal_df[col_names[k]], color = 'green', alpha = 0.2, bins = 100, range = [-1, 1], label = '0',density=True )
    ax.hist(abnormal_df[col_names[k]], color = 'red', alpha = 0.2, bins = 100, range = [-1, 1], label = '1',density=True)
    ax.legend()
    ax.set_title(col_names[k])
    k+=1
plt.tight_layout()
