# %% [markdown]
# # 필요한 라이브러리 설치

# %%
# 필요한 라이브러리 설치
from sklearn.impute import KNNImputer
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d
import sklearn
from impyute.imputation.cs import mice
from sklearn.experimental import enable_iterative_imputer
import missingno as msno
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from collections import OrderedDict
import math

# %% [markdown]
# # 파일 불러오기 - 6class

# %%
# 파일 받아오기
# 6class

simple_df = pd.read_csv('Sdf.csv')
KNN_df = pd.read_csv('Kdf.csv')
MICE_df = pd.read_csv('Mdf.csv')

# %% [markdown]
# # 파일 불러오기 - 3class

# %%
'''
# 파일 받아오기
# 3class

simple_imputer = pd.read_csv('just_df_3class')
KNN_dataframes = pd.read_csv('iterative_df_3class')
MICE_dataframe = pd.read_csv('knn_df_3class')
'''
# Out:
# "\n# 파일 받아오기\n# 3class\n\nsimple_imputer = pd.read_csv('just_df_3class')\nKNN_dataframes = pd.read_csv('iterative_df_3class')\nMICE_dataframe = pd.read_csv('knn_df_3class')\n"

# %%
MICE_df.head()
# Out:
#       attr1     attr2     attr3     attr4     attr5     attr6     attr7  \
# 0  0.831450  0.472949  0.945033  0.000046  0.904939  0.483805  0.443752
# 1  0.831466  0.473081  0.945182  0.000044  0.904937  0.483436  0.443759
# 2  0.831536  0.473296  0.944778  0.000037  0.904936  0.483436  0.443803
# 3  0.831237  0.472870  0.945156  0.000054  0.904940  0.483578  0.443617
# 4  0.831426  0.473206  0.944705  0.000034  0.904936  0.483614  0.443698
#
#       attr8     attr9    attr10  ...    attr56    attr57   attr58    attr59  \
# 0  0.002664  0.000476  0.304174  ...  0.999736  0.751235  0.00018  0.013563
# 1  0.002658  0.000533  0.304169  ...  0.999736  0.751246  0.00018  0.013563
# 2  0.002648  0.000493  0.304046  ...  0.999736  0.751425  0.00018  0.013592
# 3  0.002674  0.000467  0.304217  ...  0.999736  0.751120  0.00018  0.013563
# 4  0.002651  0.000477  0.304099  ...  0.999736  0.751274  0.00018  0.013568
#
#      attr60    attr61    attr62    attr63    attr64  bankruptcy
# 0  0.000004  0.000165  0.085542  0.000254  0.034980         0.0
# 1  0.000003  0.000147  0.085543  0.000211  0.035155         0.0
# 2  0.000004  0.000154  0.085544  0.000182  0.034972         0.0
# 3  0.000004  0.000151  0.085542  0.000246  0.034973         0.0
# 4  0.000004  0.000157  0.085543  0.000188  0.034981         0.0
#
# [5 rows x 65 columns]

# %%
KNN_df.head()
# Out:
#       attr1     attr2     attr3     attr4     attr5     attr6     attr7  \
# 0  0.831450  0.472949  0.945033  0.000046  0.904939  0.483805  0.443752
# 1  0.831466  0.473081  0.945182  0.000044  0.904937  0.483436  0.443759
# 2  0.831536  0.473296  0.944778  0.000037  0.904936  0.483436  0.443803
# 3  0.831237  0.472870  0.945156  0.000054  0.904940  0.483578  0.443617
# 4  0.831426  0.473206  0.944705  0.000034  0.904936  0.483614  0.443698
#
#       attr8     attr9    attr10  ...    attr56    attr57   attr58    attr59  \
# 0  0.002664  0.000476  0.304174  ...  0.999736  0.751235  0.00018  0.013563
# 1  0.002658  0.000533  0.304169  ...  0.999736  0.751246  0.00018  0.013563
# 2  0.002648  0.000493  0.304046  ...  0.999736  0.751425  0.00018  0.013592
# 3  0.002674  0.000467  0.304217  ...  0.999736  0.751120  0.00018  0.013563
# 4  0.002651  0.000477  0.304099  ...  0.999736  0.751274  0.00018  0.013568
#
#      attr60    attr61    attr62    attr63    attr64  bankruptcy
# 0  0.000004  0.000165  0.085542  0.000254  0.034980         0.0
# 1  0.000003  0.000147  0.085543  0.000211  0.035155         0.0
# 2  0.000004  0.000154  0.085544  0.000182  0.034972         0.0
# 3  0.000004  0.000151  0.085542  0.000246  0.034973         0.0
# 4  0.000004  0.000157  0.085543  0.000188  0.034981         0.0
#
# [5 rows x 65 columns]

# %%
simple_df.head()
# Out:
#       attr1     attr2     attr3     attr4     attr5     attr6     attr7  \
# 0  0.831450  0.472949  0.945033  0.000046  0.904939  0.483805  0.443752
# 1  0.831237  0.472870  0.945156  0.000054  0.904940  0.483578  0.443617
# 2  0.831426  0.473206  0.944705  0.000034  0.904936  0.483614  0.443698
# 3  0.831107  0.473226  0.944359  0.000029  0.904933  0.483436  0.443550
# 4  0.831042  0.472656  0.944489  0.000046  0.904934  0.483355  0.443517
#
#       attr8     attr9    attr10  ...    attr55    attr56    attr57   attr58  \
# 0  0.002664  0.000476  0.304174  ...  0.272218  0.999736  0.751235  0.00018
# 1  0.002674  0.000467  0.304217  ...  0.230838  0.999736  0.751120  0.00018
# 2  0.002651  0.000477  0.304099  ...  0.228649  0.999736  0.751274  0.00018
# 3  0.002650  0.000496  0.304087  ...  0.228247  0.999736  0.751067  0.00018
# 4  0.002783  0.000452  0.304396  ...  0.228419  0.999735  0.751042  0.00018
#
#      attr59    attr61    attr62    attr63    attr64  bankruptcy
# 0  0.013563  0.000165  0.085542  0.000254  0.034980           0
# 1  0.013563  0.000151  0.085542  0.000246  0.034973           0
# 2  0.013568  0.000157  0.085543  0.000188  0.034981           0
# 3  0.013577  0.000156  0.085543  0.000199  0.034964           0
# 4  0.013563  0.000242  0.085542  0.000269  0.034958           0
#
# [5 rows x 60 columns]

# %% [markdown]
# # x, y 나누기

# %%
Mx = MICE_df.drop(labels=['bankruptcy'], axis=1)
My = MICE_df['bankruptcy'].to_frame()

# %%
Mx.head()
# Out:
#       attr1     attr2     attr3     attr4     attr5     attr6     attr7  \
# 0  0.831450  0.472949  0.945033  0.000046  0.904939  0.483805  0.443752
# 1  0.831466  0.473081  0.945182  0.000044  0.904937  0.483436  0.443759
# 2  0.831536  0.473296  0.944778  0.000037  0.904936  0.483436  0.443803
# 3  0.831237  0.472870  0.945156  0.000054  0.904940  0.483578  0.443617
# 4  0.831426  0.473206  0.944705  0.000034  0.904936  0.483614  0.443698
#
#       attr8     attr9    attr10  ...    attr55    attr56    attr57   attr58  \
# 0  0.002664  0.000476  0.304174  ...  0.272218  0.999736  0.751235  0.00018
# 1  0.002658  0.000533  0.304169  ...  0.228538  0.999736  0.751246  0.00018
# 2  0.002648  0.000493  0.304046  ...  0.229046  0.999736  0.751425  0.00018
# 3  0.002674  0.000467  0.304217  ...  0.230838  0.999736  0.751120  0.00018
# 4  0.002651  0.000477  0.304099  ...  0.228649  0.999736  0.751274  0.00018
#
#      attr59    attr60    attr61    attr62    attr63    attr64
# 0  0.013563  0.000004  0.000165  0.085542  0.000254  0.034980
# 1  0.013563  0.000003  0.000147  0.085543  0.000211  0.035155
# 2  0.013592  0.000004  0.000154  0.085544  0.000182  0.034972
# 3  0.013563  0.000004  0.000151  0.085542  0.000246  0.034973
# 4  0.013568  0.000004  0.000157  0.085543  0.000188  0.034981
#
# [5 rows x 64 columns]

# %%
Kx = KNN_df.drop(labels=['bankruptcy'], axis=1)
Ky = KNN_df['bankruptcy'].to_frame()

# %%
Kx.head()
# Out:
#       attr1     attr2     attr3     attr4     attr5     attr6     attr7  \
# 0  0.831450  0.472949  0.945033  0.000046  0.904939  0.483805  0.443752
# 1  0.831466  0.473081  0.945182  0.000044  0.904937  0.483436  0.443759
# 2  0.831536  0.473296  0.944778  0.000037  0.904936  0.483436  0.443803
# 3  0.831237  0.472870  0.945156  0.000054  0.904940  0.483578  0.443617
# 4  0.831426  0.473206  0.944705  0.000034  0.904936  0.483614  0.443698
#
#       attr8     attr9    attr10  ...    attr55    attr56    attr57   attr58  \
# 0  0.002664  0.000476  0.304174  ...  0.272218  0.999736  0.751235  0.00018
# 1  0.002658  0.000533  0.304169  ...  0.228538  0.999736  0.751246  0.00018
# 2  0.002648  0.000493  0.304046  ...  0.229046  0.999736  0.751425  0.00018
# 3  0.002674  0.000467  0.304217  ...  0.230838  0.999736  0.751120  0.00018
# 4  0.002651  0.000477  0.304099  ...  0.228649  0.999736  0.751274  0.00018
#
#      attr59    attr60    attr61    attr62    attr63    attr64
# 0  0.013563  0.000004  0.000165  0.085542  0.000254  0.034980
# 1  0.013563  0.000003  0.000147  0.085543  0.000211  0.035155
# 2  0.013592  0.000004  0.000154  0.085544  0.000182  0.034972
# 3  0.013563  0.000004  0.000151  0.085542  0.000246  0.034973
# 4  0.013568  0.000004  0.000157  0.085543  0.000188  0.034981
#
# [5 rows x 64 columns]

# %%
Sx = simple_df.drop(labels=['bankruptcy'], axis=1)
Sy = simple_df['bankruptcy'].to_frame()

# %%
Sx.head()
# Out:
#       attr1     attr2     attr3     attr4     attr5     attr6     attr7  \
# 0  0.831450  0.472949  0.945033  0.000046  0.904939  0.483805  0.443752
# 1  0.831237  0.472870  0.945156  0.000054  0.904940  0.483578  0.443617
# 2  0.831426  0.473206  0.944705  0.000034  0.904936  0.483614  0.443698
# 3  0.831107  0.473226  0.944359  0.000029  0.904933  0.483436  0.443550
# 4  0.831042  0.472656  0.944489  0.000046  0.904934  0.483355  0.443517
#
#       attr8     attr9    attr10  ...    attr54    attr55    attr56    attr57  \
# 0  0.002664  0.000476  0.304174  ...  0.020791  0.272218  0.999736  0.751235
# 1  0.002674  0.000467  0.304217  ...  0.020792  0.230838  0.999736  0.751120
# 2  0.002651  0.000477  0.304099  ...  0.020790  0.228649  0.999736  0.751274
# 3  0.002650  0.000496  0.304087  ...  0.020784  0.228247  0.999736  0.751067
# 4  0.002783  0.000452  0.304396  ...  0.020785  0.228419  0.999735  0.751042
#
#     attr58    attr59    attr61    attr62    attr63    attr64
# 0  0.00018  0.013563  0.000165  0.085542  0.000254  0.034980
# 1  0.00018  0.013563  0.000151  0.085542  0.000246  0.034973
# 2  0.00018  0.013568  0.000157  0.085543  0.000188  0.034981
# 3  0.00018  0.013577  0.000156  0.085543  0.000199  0.034964
# 4  0.00018  0.013563  0.000242  0.085542  0.000269  0.034958
#
# [5 rows x 59 columns]

# %% [markdown]
# # Oversampling 진행

# %%
# SMOTE 패키지로 oversampling 진행
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42, k_neighbors=5)
Mdf, My = smote.fit_resample(Mx, My)

sns.countplot(x=My['bankruptcy'])
plt.title('Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')

# %%
# SMOTE 패키지로 oversampling 진행
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42, k_neighbors=5)
Kdf, Ky = smote.fit_resample(Kx, Ky)

sns.countplot(x=Ky['bankruptcy'])
plt.title('Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')

# %%
# SMOTE 패키지로 oversampling 진행
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42, k_neighbors=5)
Sdf, Sy = smote.fit_resample(Sx, Sy)

sns.countplot(x=Sy['bankruptcy'])
plt.title('Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')

# %% [markdown]
# # Train, Test 셋 나누기

# %%
from sklearn.model_selection import train_test_split # 학습, 테스트set 구분

Mx_train, Mx_test, My_train, My_test = train_test_split(Mdf, My,test_size=0.3,random_state=2022)

# %%
from sklearn.model_selection import train_test_split # 학습, 테스트set 구분

Kx_train, Kx_test, Ky_train, Ky_test = train_test_split(Kdf, Ky,test_size=0.3,random_state=2022)

# %%
from sklearn.model_selection import train_test_split # 학습, 테스트set 구분

Sx_train, Sx_test, Sy_train, Sy_test = train_test_split(Sdf, Sy,test_size=0.3,random_state=2022)

# %% [markdown]
# # 모델 구축 ( 모델 이름 )

# %%
from lightgbm import LGBMClassifier

# %%
Mlgbm_wrapper = LGBMClassifier(n_estimators=100)


evals = [(Mx_test,My_test)]
Mlgbm_wrapper.fit(Mx_train,My_train,early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals,verbose=True)
preds = Mlgbm_wrapper.predict(Mx_test)
# Out:
# [1]	valid_0's multi_logloss: 1.61321
# [2]	valid_0's multi_logloss: 1.49134
# [3]	valid_0's multi_logloss: 1.3972
# [4]	valid_0's multi_logloss: 1.31922
# [5]	valid_0's multi_logloss: 1.25259
# [6]	valid_0's multi_logloss: 1.195
# [7]	valid_0's multi_logloss: 1.14624
# [8]	valid_0's multi_logloss: 1.10269
# [9]	valid_0's multi_logloss: 1.06357
# [10]	valid_0's multi_logloss: 1.02769
# [11]	valid_0's multi_logloss: 0.994409
# [12]	valid_0's multi_logloss: 0.964564
# [13]	valid_0's multi_logloss: 0.938724
# [14]	valid_0's multi_logloss: 0.913292
# [15]	valid_0's multi_logloss: 0.89076
# [16]	valid_0's multi_logloss: 0.867747
# [17]	valid_0's multi_logloss: 0.847071
# [18]	valid_0's multi_logloss: 0.826702
# [19]	valid_0's multi_logloss: 0.806297
# [20]	valid_0's multi_logloss: 0.789228
# [21]	valid_0's multi_logloss: 0.772808
# [22]	valid_0's multi_logloss: 0.755669
# [23]	valid_0's multi_logloss: 0.739309
# [24]	valid_0's multi_logloss: 0.723954
# [25]	valid_0's multi_logloss: 0.709207
# [26]	valid_0's multi_logloss: 0.694928
# [27]	valid_0's multi_logloss: 0.680131
# [28]	valid_0's multi_logloss: 0.667602
# [29]	valid_0's multi_logloss: 0.655583
# [30]	valid_0's multi_logloss: 0.644581
# [31]	valid_0's multi_logloss: 0.632855
# [32]	valid_0's multi_logloss: 0.620789
# [33]	valid_0's multi_logloss: 0.610045
# [34]	valid_0's multi_logloss: 0.599254
# [35]	valid_0's multi_logloss: 0.588838
# [36]	valid_0's multi_logloss: 0.578778
# [37]	valid_0's multi_logloss: 0.568672
# [38]	valid_0's multi_logloss: 0.5583
# [39]	valid_0's multi_logloss: 0.548721
# [40]	valid_0's multi_logloss: 0.539748
# [41]	valid_0's multi_logloss: 0.531475
# [42]	valid_0's multi_logloss: 0.52296
# [43]	valid_0's multi_logloss: 0.514902
# [44]	valid_0's multi_logloss: 0.506484
# [45]	valid_0's multi_logloss: 0.498642
# [46]	valid_0's multi_logloss: 0.491173
# [47]	valid_0's multi_logloss: 0.483614
# [48]	valid_0's multi_logloss: 0.476383
# [49]	valid_0's multi_logloss: 0.468402
# [50]	valid_0's multi_logloss: 0.46176
# [51]	valid_0's multi_logloss: 0.454908
# [52]	valid_0's multi_logloss: 0.448268
# [53]	valid_0's multi_logloss: 0.442874
# [54]	valid_0's multi_logloss: 0.436432
# [55]	valid_0's multi_logloss: 0.430253
# [56]	valid_0's multi_logloss: 0.423517
# [57]	valid_0's multi_logloss: 0.417218
# [58]	valid_0's multi_logloss: 0.411478
# [59]	valid_0's multi_logloss: 0.405572
# [60]	valid_0's multi_logloss: 0.39989
# [61]	valid_0's multi_logloss: 0.394332
# [62]	valid_0's multi_logloss: 0.389283
# [63]	valid_0's multi_logloss: 0.384468
# [64]	valid_0's multi_logloss: 0.379892
# [65]	valid_0's multi_logloss: 0.375037
# [66]	valid_0's multi_logloss: 0.369262
# [67]	valid_0's multi_logloss: 0.364239
# [68]	valid_0's multi_logloss: 0.359042
# [69]	valid_0's multi_logloss: 0.354797
# [70]	valid_0's multi_logloss: 0.350719
# [71]	valid_0's multi_logloss: 0.346422
# [72]	valid_0's multi_logloss: 0.341749
# [73]	valid_0's multi_logloss: 0.337673
# [74]	valid_0's multi_logloss: 0.333662
# [75]	valid_0's multi_logloss: 0.329587
# [76]	valid_0's multi_logloss: 0.325706
# [77]	valid_0's multi_logloss: 0.321305
# [78]	valid_0's multi_logloss: 0.316806
# [79]	valid_0's multi_logloss: 0.312592
# [80]	valid_0's multi_logloss: 0.308441
# [81]	valid_0's multi_logloss: 0.304206
# [82]	valid_0's multi_logloss: 0.300234
# [83]	valid_0's multi_logloss: 0.297214
# [84]	valid_0's multi_logloss: 0.293897
# [85]	valid_0's multi_logloss: 0.290281
# [86]	valid_0's multi_logloss: 0.286881
# [87]	valid_0's multi_logloss: 0.283489
# [88]	valid_0's multi_logloss: 0.280007
# [89]	valid_0's multi_logloss: 0.276723
# [90]	valid_0's multi_logloss: 0.273519
# [91]	valid_0's multi_logloss: 0.270804
# [92]	valid_0's multi_logloss: 0.267347
# [93]	valid_0's multi_logloss: 0.264371
# [94]	valid_0's multi_logloss: 0.26156
# [95]	valid_0's multi_logloss: 0.258838
# [96]	valid_0's multi_logloss: 0.256202
# [97]	valid_0's multi_logloss: 0.253299
# [98]	valid_0's multi_logloss: 0.2502
# [99]	valid_0's multi_logloss: 0.247463
# [100]	valid_0's multi_logloss: 0.244968

# %%
Klgbm_wrapper = LGBMClassifier(n_estimators=100)


evals = [(Kx_test,Ky_test)]
Klgbm_wrapper.fit(Kx_train,Ky_train,early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals,verbose=True)
preds = Klgbm_wrapper.predict(Kx_test)
# Out:
# [1]	valid_0's multi_logloss: 1.69339
# [2]	valid_0's multi_logloss: 1.61745
# [3]	valid_0's multi_logloss: 1.55496
# [4]	valid_0's multi_logloss: 1.49511
# [5]	valid_0's multi_logloss: 1.44594
# [6]	valid_0's multi_logloss: 1.39979
# [7]	valid_0's multi_logloss: 1.35862
# [8]	valid_0's multi_logloss: 1.32082
# [9]	valid_0's multi_logloss: 1.28475
# [10]	valid_0's multi_logloss: 1.24994
# [11]	valid_0's multi_logloss: 1.21986
# [12]	valid_0's multi_logloss: 1.19241
# [13]	valid_0's multi_logloss: 1.16485
# [14]	valid_0's multi_logloss: 1.13723
# [15]	valid_0's multi_logloss: 1.11351
# [16]	valid_0's multi_logloss: 1.09032
# [17]	valid_0's multi_logloss: 1.06704
# [18]	valid_0's multi_logloss: 1.0459
# [19]	valid_0's multi_logloss: 1.02331
# [20]	valid_0's multi_logloss: 1.00205
# [21]	valid_0's multi_logloss: 0.984489
# [22]	valid_0's multi_logloss: 0.963677
# [23]	valid_0's multi_logloss: 0.94605
# [24]	valid_0's multi_logloss: 0.92759
# [25]	valid_0's multi_logloss: 0.909532
# [26]	valid_0's multi_logloss: 0.894776
# [27]	valid_0's multi_logloss: 0.878427
# [28]	valid_0's multi_logloss: 0.863811
# [29]	valid_0's multi_logloss: 0.851134
# [30]	valid_0's multi_logloss: 0.837365
# [31]	valid_0's multi_logloss: 0.823561
# [32]	valid_0's multi_logloss: 0.810657
# [33]	valid_0's multi_logloss: 0.798631
# [34]	valid_0's multi_logloss: 0.783449
# [35]	valid_0's multi_logloss: 0.772219
# [36]	valid_0's multi_logloss: 0.762241
# [37]	valid_0's multi_logloss: 0.751985
# [38]	valid_0's multi_logloss: 0.741803
# [39]	valid_0's multi_logloss: 0.730701
# [40]	valid_0's multi_logloss: 0.720007
# [41]	valid_0's multi_logloss: 0.710232
# [42]	valid_0's multi_logloss: 0.701761
# [43]	valid_0's multi_logloss: 0.69005
# [44]	valid_0's multi_logloss: 0.680793
# [45]	valid_0's multi_logloss: 0.671088
# [46]	valid_0's multi_logloss: 0.66295
# [47]	valid_0's multi_logloss: 0.656002
# [48]	valid_0's multi_logloss: 0.646313
# [49]	valid_0's multi_logloss: 0.638779
# [50]	valid_0's multi_logloss: 0.63138
# [51]	valid_0's multi_logloss: 0.623981
# [52]	valid_0's multi_logloss: 0.61661
# [53]	valid_0's multi_logloss: 0.607913
# [54]	valid_0's multi_logloss: 0.599604
# [55]	valid_0's multi_logloss: 0.592887
# [56]	valid_0's multi_logloss: 0.586852
# [57]	valid_0's multi_logloss: 0.578534
# [58]	valid_0's multi_logloss: 0.571394
# [59]	valid_0's multi_logloss: 0.564798
# [60]	valid_0's multi_logloss: 0.558466
# [61]	valid_0's multi_logloss: 0.551724
# [62]	valid_0's multi_logloss: 0.545978
# [63]	valid_0's multi_logloss: 0.537308
# [64]	valid_0's multi_logloss: 0.531037
# [65]	valid_0's multi_logloss: 0.524243
# [66]	valid_0's multi_logloss: 0.518243
# [67]	valid_0's multi_logloss: 0.512831
# [68]	valid_0's multi_logloss: 0.506538
# [69]	valid_0's multi_logloss: 0.499152
# [70]	valid_0's multi_logloss: 0.492923
# [71]	valid_0's multi_logloss: 0.487921
# [72]	valid_0's multi_logloss: 0.482426
# [73]	valid_0's multi_logloss: 0.477
# [74]	valid_0's multi_logloss: 0.47132
# [75]	valid_0's multi_logloss: 0.465379
# [76]	valid_0's multi_logloss: 0.460395
# [77]	valid_0's multi_logloss: 0.454922
# [78]	valid_0's multi_logloss: 0.449335
# [79]	valid_0's multi_logloss: 0.443627
# [80]	valid_0's multi_logloss: 0.439244
# [81]	valid_0's multi_logloss: 0.433769
# [82]	valid_0's multi_logloss: 0.428949
# [83]	valid_0's multi_logloss: 0.425149
# [84]	valid_0's multi_logloss: 0.419705
# [85]	valid_0's multi_logloss: 0.414068
# [86]	valid_0's multi_logloss: 0.408968
# [87]	valid_0's multi_logloss: 0.404335
# [88]	valid_0's multi_logloss: 0.400523
# [89]	valid_0's multi_logloss: 0.396944
# [90]	valid_0's multi_logloss: 0.392377
# [91]	valid_0's multi_logloss: 0.387231
# [92]	valid_0's multi_logloss: 0.383908
# [93]	valid_0's multi_logloss: 0.380777
# [94]	valid_0's multi_logloss: 0.377469
# [95]	valid_0's multi_logloss: 0.373494
# [96]	valid_0's multi_logloss: 0.368841
# [97]	valid_0's multi_logloss: 0.365026
# [98]	valid_0's multi_logloss: 0.361156
# [99]	valid_0's multi_logloss: 0.35796
# [100]	valid_0's multi_logloss: 0.354521

# %%
Slgbm_wrapper = LGBMClassifier(n_estimators=100)


evals = [(Sx_test,Sy_test)]
Slgbm_wrapper.fit(Sx_train,Sy_train,early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals,verbose=True)
preds = Slgbm_wrapper.predict(Sx_test)
# Out:
# [1]	valid_0's multi_logloss: 1.71773
# [2]	valid_0's multi_logloss: 1.65599
# [3]	valid_0's multi_logloss: 1.60552
# [4]	valid_0's multi_logloss: 1.55998
# [5]	valid_0's multi_logloss: 1.51831
# [6]	valid_0's multi_logloss: 1.48237
# [7]	valid_0's multi_logloss: 1.44906
# [8]	valid_0's multi_logloss: 1.41866
# [9]	valid_0's multi_logloss: 1.38928
# [10]	valid_0's multi_logloss: 1.36308
# [11]	valid_0's multi_logloss: 1.33854
# [12]	valid_0's multi_logloss: 1.31539
# [13]	valid_0's multi_logloss: 1.29342
# [14]	valid_0's multi_logloss: 1.27117
# [15]	valid_0's multi_logloss: 1.24945
# [16]	valid_0's multi_logloss: 1.22906
# [17]	valid_0's multi_logloss: 1.20859
# [18]	valid_0's multi_logloss: 1.19029
# [19]	valid_0's multi_logloss: 1.17193
# [20]	valid_0's multi_logloss: 1.15376
# [21]	valid_0's multi_logloss: 1.13642
# [22]	valid_0's multi_logloss: 1.11988
# [23]	valid_0's multi_logloss: 1.10452
# [24]	valid_0's multi_logloss: 1.08886
# [25]	valid_0's multi_logloss: 1.07563
# [26]	valid_0's multi_logloss: 1.06059
# [27]	valid_0's multi_logloss: 1.04685
# [28]	valid_0's multi_logloss: 1.03397
# [29]	valid_0's multi_logloss: 1.02228
# [30]	valid_0's multi_logloss: 1.00978
# [31]	valid_0's multi_logloss: 0.996398
# [32]	valid_0's multi_logloss: 0.984041
# [33]	valid_0's multi_logloss: 0.972885
# [34]	valid_0's multi_logloss: 0.961777
# [35]	valid_0's multi_logloss: 0.950862
# [36]	valid_0's multi_logloss: 0.939029
# [37]	valid_0's multi_logloss: 0.928228
# [38]	valid_0's multi_logloss: 0.918332
# [39]	valid_0's multi_logloss: 0.9091
# [40]	valid_0's multi_logloss: 0.898931
# [41]	valid_0's multi_logloss: 0.890215
# [42]	valid_0's multi_logloss: 0.880649
# [43]	valid_0's multi_logloss: 0.872256
# [44]	valid_0's multi_logloss: 0.863006
# [45]	valid_0's multi_logloss: 0.853833
# [46]	valid_0's multi_logloss: 0.844741
# [47]	valid_0's multi_logloss: 0.836933
# [48]	valid_0's multi_logloss: 0.829301
# [49]	valid_0's multi_logloss: 0.821572
# [50]	valid_0's multi_logloss: 0.813805
# [51]	valid_0's multi_logloss: 0.806331
# [52]	valid_0's multi_logloss: 0.797246
# [53]	valid_0's multi_logloss: 0.789554
# [54]	valid_0's multi_logloss: 0.782886
# [55]	valid_0's multi_logloss: 0.774788
# [56]	valid_0's multi_logloss: 0.768399
# [57]	valid_0's multi_logloss: 0.759684
# [58]	valid_0's multi_logloss: 0.75319
# [59]	valid_0's multi_logloss: 0.747022
# [60]	valid_0's multi_logloss: 0.740684
# [61]	valid_0's multi_logloss: 0.734
# [62]	valid_0's multi_logloss: 0.727458
# [63]	valid_0's multi_logloss: 0.720592
# [64]	valid_0's multi_logloss: 0.713074
# [65]	valid_0's multi_logloss: 0.706497
# [66]	valid_0's multi_logloss: 0.700332
# [67]	valid_0's multi_logloss: 0.694741
# [68]	valid_0's multi_logloss: 0.689391
# [69]	valid_0's multi_logloss: 0.681975
# [70]	valid_0's multi_logloss: 0.675751
# [71]	valid_0's multi_logloss: 0.670199
# [72]	valid_0's multi_logloss: 0.664082
# [73]	valid_0's multi_logloss: 0.65842
# [74]	valid_0's multi_logloss: 0.652127
# [75]	valid_0's multi_logloss: 0.645963
# [76]	valid_0's multi_logloss: 0.64014
# [77]	valid_0's multi_logloss: 0.633873
# [78]	valid_0's multi_logloss: 0.628794
# [79]	valid_0's multi_logloss: 0.623551
# [80]	valid_0's multi_logloss: 0.618795
# [81]	valid_0's multi_logloss: 0.613027
# [82]	valid_0's multi_logloss: 0.607437
# [83]	valid_0's multi_logloss: 0.601871
# [84]	valid_0's multi_logloss: 0.596902
# [85]	valid_0's multi_logloss: 0.591265
# [86]	valid_0's multi_logloss: 0.586478
# [87]	valid_0's multi_logloss: 0.581927
# [88]	valid_0's multi_logloss: 0.576467
# [89]	valid_0's multi_logloss: 0.572587
# [90]	valid_0's multi_logloss: 0.567771
# [91]	valid_0's multi_logloss: 0.562381
# [92]	valid_0's multi_logloss: 0.557563
# [93]	valid_0's multi_logloss: 0.553041
# [94]	valid_0's multi_logloss: 0.547072
# [95]	valid_0's multi_logloss: 0.54291
# [96]	valid_0's multi_logloss: 0.537883
# [97]	valid_0's multi_logloss: 0.533328
# [98]	valid_0's multi_logloss: 0.529456
# [99]	valid_0's multi_logloss: 0.525553
# [100]	valid_0's multi_logloss: 0.520964

# %% [markdown]
# # 모델 예측

# %%
My_pred=Mlgbm_wrapper.predict(Mx_test)

# %%
Ky_pred=Klgbm_wrapper.predict(Kx_test)

# %%
Sy_pred=Slgbm_wrapper.predict(Sx_test)

# %% [markdown]
# # 예측 정확도 확인

# %%
print("훈련 세트 정확도: {:.3f}".format(Mlgbm_wrapper.score(Mx_train, My_train)))
print("테스트 세트 정확도: {:.3f}".format(Mlgbm_wrapper.score(Mx_test, My_test)))
# Out:
# 훈련 세트 정확도: 0.981
# 테스트 세트 정확도: 0.973

# %%
print("훈련 세트 정확도: {:.3f}".format(Klgbm_wrapper.score(Kx_train, Ky_train)))
print("테스트 세트 정확도: {:.3f}".format(Klgbm_wrapper.score(Kx_test, Ky_test)))
# Out:
# 훈련 세트 정확도: 0.968
# 테스트 세트 정확도: 0.958

# %%
print("훈련 세트 정확도: {:.3f}".format(Slgbm_wrapper.score(Sx_train, Sy_train)))
print("테스트 세트 정확도: {:.3f}".format(Slgbm_wrapper.score(Sx_test, Sy_test)))
# Out:
# 훈련 세트 정확도: 0.934
# 테스트 세트 정확도: 0.920

# %% [markdown]
# # 성능 지표 확인 ( + Confusion Matrix )

# %%
import sklearn.metrics as mt # 성능지표를 계산하기 위해 import
# 학습결과 평가
#print("Train_Accuracy : ", model.score(MX_train, My_train), '\n')
#print("Test_Accuracy : ", model.score(MX_test, My_test), '\n')

# 다중 클래스 분류일 경우 average='micro' 를 하이퍼파라미터로 넣어줌(accuracy, matrix 제외)
accuracy = mt.accuracy_score(My_test, My_pred)
recall = mt.recall_score(My_test, My_pred,average='micro')
precision = mt.precision_score(My_test, My_pred,average='micro')
f1_score = mt.f1_score(My_test, My_pred,average='micro')
matrix = mt.confusion_matrix(My_test, My_pred)

print('Accuracy: ', format(accuracy,'.2f'),'\n')
print('Recall: ', format(recall,'.2f'),'\n')
print('Precision: ', format(precision,'.2f'),'\n')
print('F1_score: ', format(f1_score,'.2f'),'\n')
print('Confusion Matrix:','\n', matrix)
# Out:
# Accuracy:  0.97
#
# Recall:  0.97
#
# Precision:  0.97
#
# F1_score:  0.97
#
# Confusion Matrix:
#  [[12142    99    91    57    26    14]
#  [   57 12005   154    48     9     5]
#  [  101   149 11835   182    63    11]
#  [   68   145   225 11735    93     8]
#  [   40    33    72   116 11708    26]
#  [   12     8     6    18    59 12220]]

# %%
import sklearn.metrics as mt # 성능지표를 계산하기 위해 import
# 학습결과 평가
#print("Train_Accuracy : ", model.score(KX_train, Ky_train), '\n')
#print("Test_Accuracy : ", model.score(KX_test, Ky_test), '\n')

# 다중 클래스 분류일 경우 average='micro' 를 하이퍼파라미터로 넣어줌(accuracy, matrix 제외)
accuracy = mt.accuracy_score(Ky_test, Ky_pred)
recall = mt.recall_score(Ky_test, Ky_pred,average='micro')
precision = mt.precision_score(Ky_test, Ky_pred,average='micro')
f1_score = mt.f1_score(Ky_test, Ky_pred,average='micro')
matrix = mt.confusion_matrix(Ky_test, Ky_pred)

print('Accuracy: ', format(accuracy,'.2f'),'\n')
print('Recall: ', format(recall,'.2f'),'\n')
print('Precision: ', format(precision,'.2f'),'\n')
print('F1_score: ', format(f1_score,'.2f'),'\n')
print('Confusion Matrix:','\n', matrix)
# Out:
# Accuracy:  0.96
#
# Recall:  0.96
#
# Precision:  0.96
#
# F1_score:  0.96
#
# Confusion Matrix:
#  [[11868   160   111   145    65    80]
#  [   83 11849    98    94    78    76]
#  [  111   205 11475   174   147   229]
#  [   94   159   111 11566   127   217]
#  [   95    71    61    50 11531   187]
#  [   24     9     8     8    19 12255]]

# %%
import sklearn.metrics as mt # 성능지표를 계산하기 위해 import
# 학습결과 평가
#print("Train_Accuracy : ", model.score(SX_train, Sy_train), '\n')
#print("Test_Accuracy : ", model.score(SX_test, Sy_test), '\n')

# 다중 클래스 분류일 경우 average='micro' 를 하이퍼파라미터로 넣어줌(accuracy, matrix 제외)
accuracy = mt.accuracy_score(Sy_test, Sy_pred)
recall = mt.recall_score(Sy_test, Sy_pred,average='micro')
precision = mt.precision_score(Sy_test, Sy_pred,average='micro')
f1_score = mt.f1_score(Sy_test, Sy_pred,average='micro')
matrix = mt.confusion_matrix(Sy_test, Sy_pred)

print('Accuracy: ', format(accuracy,'.2f'),'\n')
print('Recall: ', format(recall,'.2f'),'\n')
print('Precision: ', format(precision,'.2f'),'\n')
print('F1_score: ', format(f1_score,'.2f'),'\n')
print('Confusion Matrix:','\n', matrix)
# Out:
# Accuracy:  0.92
#
# Recall:  0.92
#
# Precision:  0.92
#
# F1_score:  0.92
#
# Confusion Matrix:
#  [[10750   206   158   149   134   163]
#  [   70 10798   184    86   133   146]
#  [  175   388 10015   287   330   301]
#  [  150   230   325  9959   311   406]
#  [  113   166   157   179 10473   379]
#  [   31    18    36    28    32 11226]]

# %%
from lightgbm import plot_importance

fig, ax =plt.subplots(figsize=(10,12))
plot_importance(Mlgbm_wrapper,ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
from lightgbm import plot_importance

fig, ax =plt.subplots(figsize=(10,12))
plot_importance(Klgbm_wrapper,ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
from lightgbm import plot_importance

fig, ax =plt.subplots(figsize=(10,12))
plot_importance(Slgbm_wrapper,ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
